# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\IT-Complex\Desktop\DataAnylsis\cricket.csv')
df
# Out:
#                        Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0      RN ten Doeschate (NED)  2006-2011   33    32   9   1541   119  67.00
# 1          Shubman Gill (IND)  2019-2023   35    35   6   1917   208  66.10
# 2              DJ Malan (ENG)  2019-2023   22    22   4   1060   134  58.88
# 3      HE van der Dussen (SA)  2019-2023   50    44  10   1982   134  58.29
# 4            Babar Azam (PAK)  2015-2023  109   106  12   5414   158  57.59
# ..                        ...        ...  ...   ...  ..    ...   ...    ...
# 95  Inzamam-ul-Haq (Asia/PAK)  1991-2007  378   350  53  11739  137*  39.52
# 96       NH Fairbrother (ENG)  1987-1999   75    71  18   2092   113  39.47
# 97             ME Waugh (AUS)  1988-2002  244   236  20   8500   173  39.35
# 98              AJ Lamb (ENG)  1982-1992  122   118  16   4010   118  39.31
# 99       EJG Morgan (ENG/IRE)  2006-2022  248   230  34   7701   148  39.29
#
#        BF      SR 100  50   0   4s   6s
# ...

# %%
df = df.rename(columns={
    'Mat':'Matches','Inns':'Innings','NO':'Not Outs','HS':'Higest Score','BF':'Balls Faced','SR':'Strike Rate'
})
df
# Out:
#                        Player       Span  Matches  Innings  Not Outs   Runs  \
# 0      RN ten Doeschate (NED)  2006-2011       33       32         9   1541
# 1          Shubman Gill (IND)  2019-2023       35       35         6   1917
# 2              DJ Malan (ENG)  2019-2023       22       22         4   1060
# 3      HE van der Dussen (SA)  2019-2023       50       44        10   1982
# 4            Babar Azam (PAK)  2015-2023      109      106        12   5414
# ..                        ...        ...      ...      ...       ...    ...
# 95  Inzamam-ul-Haq (Asia/PAK)  1991-2007      378      350        53  11739
# 96       NH Fairbrother (ENG)  1987-1999       75       71        18   2092
# 97             ME Waugh (AUS)  1988-2002      244      236        20   8500
# 98              AJ Lamb (ENG)  1982-1992      122      118        16   4010
# 99       EJG Morgan (ENG/IRE)  2006-2022      248      230        34   7701
#
# ...

# %%
df.isnull().any()
# Out:
# Player          False
# Span            False
# Matches         False
# Innings         False
# Not Outs        False
# Runs            False
# Higest Score    False
# Ave             False
# Balls Faced     False
# Strike Rate     False
# 100             False
# 50              False
# 0               False
# 4s              False
# 6s              False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df['Span']
# Out:
# 0     2006-2011
# 1     2019-2023
# 2     2019-2023
# 3     2019-2023
# 4     2015-2023
#         ...
# 95    1991-2007
# 96    1987-1999
# 97    1988-2002
# 98    1982-1992
# 99    2006-2022
# Name: Span, Length: 100, dtype: object

# %%
df['Span'].str.split(pat='-')
# Out:
# 0     [2006, 2011]
# 1     [2019, 2023]
# 2     [2019, 2023]
# 3     [2019, 2023]
# 4     [2015, 2023]
#           ...
# 95    [1991, 2007]
# 96    [1987, 1999]
# 97    [1988, 2002]
# 98    [1982, 1992]
# 99    [2006, 2022]
# Name: Span, Length: 100, dtype: object

# %%
df['First_year'] = df['Span'].str.split(pat='-').str[0]

# %%
df['Final_year'] = df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#        Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF      SR  \
# 0        NED)  2006-2011   33    32   9   1541   119  67.00   1757   87.70
# 1        IND)  2019-2023   35    35   6   1917   208  66.10   1864  102.84
# 2        ENG)  2019-2023   22    22   4   1060   134  58.88   1112   95.32
# 3         SA)  2019-2023   50    44  10   1982   134  58.29   2217   89.40
# 4        PAK)  2015-2023  109   106  12   5414   158  57.59   6087   88.94
# ..        ...        ...  ...   ...  ..    ...   ...    ...    ...     ...
# 95  Asia/PAK)  1991-2007  378   350  53  11739  137*  39.52  15812   74.24
# 96       ENG)  1987-1999   75    71  18   2092   113  39.47   2903   72.06
# 97       AUS)  1988-2002  244   236  20   8500   173  39.35  11053   76.90
# 98       ENG)  1982-1992  122   118  16   4010   118  39.31   5308   75.54
# 99   ENG/IRE)  2006-2022  248   230  34   7701   148  39.29   8447   91.16
#
#    100  50   0   4s   6s  County
# 0    5   9   1  130   29     NaN
# ...

# %%
df = df.drop(['Span'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\IT-Complex\Desktop\DataAnylsis\data.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/IT-Complex/Desktop/DataAnylsis/data.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df = df.drop(['Span'], axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/IT-Complex/Desktop/DataAnylsis/data.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
# ...

# %%
df.head()
# Out:
#                    Player  Matches  Innings  Not Outs  Runs Higest Score  \
# 0  RN ten Doeschate (NED)       33       32         9  1541          119
# 1      Shubman Gill (IND)       35       35         6  1917          208
# 2          DJ Malan (ENG)       22       22         4  1060          134
# 3  HE van der Dussen (SA)       50       44        10  1982          134
# 4        Babar Azam (PAK)      109      106        12  5414          158
#
#      Ave  Balls Faced  Strike Rate 100  50  0   4s  6s First_year Final_year
# 0  67.00         1757        87.70   5   9  1  130  29       2006       2011
# 1  66.10         1864       102.84   6   9  1  213  40       2019       2023
# 2  58.88         1112        95.32   5   5  5  102  23       2019       2023
# 3  58.29         2217        89.40   5  12  1  153  35       2019       2023
# 4  57.59         6087        88.94  19  28  4  488  56       2015       2023

# %%
df['Player']
# Out:
# 0          NED)
# 1          IND)
# 2          ENG)
# 3           SA)
# 4          PAK)
#         ...
# 95    Asia/PAK)
# 96         ENG)
# 97         AUS)
# 98         ENG)
# 99     ENG/IRE)
# Name: Player, Length: 100, dtype: object

# %%
df
# Out:
#                        Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0      RN ten Doeschate (NED)  2006-2011   33    32   9   1541   119  67.00
# 1          Shubman Gill (IND)  2019-2023   35    35   6   1917   208  66.10
# 2              DJ Malan (ENG)  2019-2023   22    22   4   1060   134  58.88
# 3      HE van der Dussen (SA)  2019-2023   50    44  10   1982   134  58.29
# 4            Babar Azam (PAK)  2015-2023  109   106  12   5414   158  57.59
# ..                        ...        ...  ...   ...  ..    ...   ...    ...
# 95  Inzamam-ul-Haq (Asia/PAK)  1991-2007  378   350  53  11739  137*  39.52
# 96       NH Fairbrother (ENG)  1987-1999   75    71  18   2092   113  39.47
# 97             ME Waugh (AUS)  1988-2002  244   236  20   8500   173  39.35
# 98              AJ Lamb (ENG)  1982-1992  122   118  16   4010   118  39.31
# 99       EJG Morgan (ENG/IRE)  2006-2022  248   230  34   7701   148  39.29
#
#        BF      SR 100  50   0   4s   6s
# ...

# %%
df['Player']
# Out:
# 0        RN ten Doeschate (NED)
# 1            Shubman Gill (IND)
# 2                DJ Malan (ENG)
# 3        HE van der Dussen (SA)
# 4              Babar Azam (PAK)
#                 ...
# 95    Inzamam-ul-Haq (Asia/PAK)
# 96         NH Fairbrother (ENG)
# 97               ME Waugh (AUS)
# 98                AJ Lamb (ENG)
# 99         EJG Morgan (ENG/IRE)
# Name: Player, Length: 100, dtype: object

# %%
df['Player'].str.split(pat='(')
# Out:
# 0        [RN ten Doeschate , NED)]
# 1            [Shubman Gill , IND)]
# 2                [DJ Malan , ENG)]
# 3        [HE van der Dussen , SA)]
# 4              [Babar Azam , PAK)]
#                   ...
# 95    [Inzamam-ul-Haq , Asia/PAK)]
# 96         [NH Fairbrother , ENG)]
# 97               [ME Waugh , AUS)]
# 98                [AJ Lamb , ENG)]
# 99         [EJG Morgan , ENG/IRE)]
# Name: Player, Length: 100, dtype: object

# %%
df['County'] = df['Player'].str.split(pat='(').str[1]

# %%
df['County'] = df['County'].str.split(pat=')').str[0]

# %%
df['County']
# Out:
# 0          NED
# 1          IND
# 2          ENG
# 3           SA
# 4          PAK
#         ...
# 95    Asia/PAK
# 96         ENG
# 97         AUS
# 98         ENG
# 99     ENG/IRE
# Name: County, Length: 100, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#                 Player       Span  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0    RN ten Doeschate   2006-2011   33    32   9   1541   119  67.00   1757
# 1        Shubman Gill   2019-2023   35    35   6   1917   208  66.10   1864
# 2            DJ Malan   2019-2023   22    22   4   1060   134  58.88   1112
# 3   HE van der Dussen   2019-2023   50    44  10   1982   134  58.29   2217
# 4          Babar Azam   2015-2023  109   106  12   5414   158  57.59   6087
# ..                 ...        ...  ...   ...  ..    ...   ...    ...    ...
# 95     Inzamam-ul-Haq   1991-2007  378   350  53  11739  137*  39.52  15812
# 96     NH Fairbrother   1987-1999   75    71  18   2092   113  39.47   2903
# 97           ME Waugh   1988-2002  244   236  20   8500   173  39.35  11053
# 98            AJ Lamb   1982-1992  122   118  16   4010   118  39.31   5308
# 99         EJG Morgan   2006-2022  248   230  34   7701   148  39.29   8447
#
#         SR 100  50   0   4s   6s    County
# ...

# %%
df.dtypes
# Out:
# Player     object
# Span       object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Ave       float64
# BF          int64
# SR        float64
# 100        object
# 50          int64
# 0          object
# 4s          int64
# 6s          int64
# County     object
# dtype: object
